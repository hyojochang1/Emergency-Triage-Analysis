# %%
import pandas as pd 
import numpy as np

df = pd.read_csv("data/data.csv", sep=';', decimal=",", encoding='cp1252')
pd.set_option('display.max_columns',None)
df.columns = df.columns.str.strip()
df.head()
# Out:
#    Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 0      2    2   71                         3             3       2
# 1      1    1   56                        12             3       2
# 2      2    1   68                         8             2       2
# 3      1    2   71                         8             1       1
# 4      1    2   58                         4             3       1
#
#        Chief_complain  Mental  Pain NRS_pain  SBP  DBP   HR  RR    BT  \
# 0   right ocular pain       1     1        2  160  100   84  18  36.6
# 1  right forearm burn       1     1        2  137   75   60  20  36.5
# 2        arm pain, Lt       1     1        2  130   80  102  20  36.6
# 3     ascites tapping       1     1        3  139   94   88  20  36.5
# 4     distension, abd       1     1        3   91   67   93  18  36.5
#
#   Saturation  KTAS_RN                               Diagnosis in ED  \
# 0        100        2                              Corneal abrasion
# 1        NaN        4             Burn of hand, firts degree dorsum
# 2         98        4  Fracture of surgical neck of humerus, closed
# 3        NaN        4        Alcoholic liver cirrhosis with ascites
# 4        NaN        4                                       Ascites
#
#    Disposition  KTAS_expert  Error_group  Length of stay_min  \
# 0            1            4            2                  86
# 1            1            5            4                  64
# 2            2            5            4                 862
# 3            1            5            6                 108
# 4            1            5            8                 109
#
#    KTAS duration_min  mistriage
# 0               5.00          1
# 1               3.95          1
# 2               1.00          1
# 3               9.83          1
# 4               6.60          1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1267 entries, 0 to 1266
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Group                     1267 non-null   int64
#  1   Sex                       1267 non-null   int64
#  2   Age                       1267 non-null   int64
#  3   Patients number per hour  1267 non-null   int64
#  4   Arrival mode              1267 non-null   int64
#  5   Injury                    1267 non-null   int64
#  6   Chief_complain            1267 non-null   str
#  7   Mental                    1267 non-null   int64
#  8   Pain                      1267 non-null   int64
#  9   NRS_pain                  1267 non-null   str
#  10  SBP                       1267 non-null   str
#  11  DBP                       1267 non-null   str
#  12  HR                        1267 non-null   str
#  13  RR                        1267 non-null   str
#  14  BT                        1267 non-null   str
#  15  Saturation                579 non-null    str
#  16  KTAS_RN                   1267 non-null   int64
#  17  Diagnosis in ED           1265 non-null   str
#  18  Disposition               1267 non-null   int64
#  19  KTAS_expert               1267 non-null   int64
#  20  Error_group               1267 non-null   int64
#  21  Length of stay_min        1267 non-null   int64
#  22  KTAS duration_min         1267 non-null   float64
#  23  mistriage                 1267 non-null   int64
# dtypes: float64(1), int64(14), str(9)
# memory usage: 237.7 KB

# %%
df.tail()
# Out:
#       Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 1262      2    2   79                         5             2       1
# 1263      2    2   81                         2             3       1
# 1264      2    2   81                        17             2       1
# 1265      2    1   81                         2             2       2
# 1266      2    2   87                         8             4       1
#
#           Chief_complain  Mental  Pain NRS_pain  SBP  DBP  HR  RR    BT  \
# 1262       mental change       1     0    #BOÞ!  120   80  86  22  36.4
# 1263             dysuria       1     0    #BOÞ!  120   80  94  20  36.4
# 1264           dizziness       1     0    #BOÞ!  130   90  80  20  36.2
# 1265  Sensory, Decreased       1     0    #BOÞ!  170  100  78  20  36.6
# 1266           orthopnea       1     0    #BOÞ!  150   80  62  20  36.2
#
#      Saturation  KTAS_RN                                    Diagnosis in ED  \
# 1262         95        2  Cerebral infarction due to unspecified occlusi...
# 1263         97        4                                            Dysuria
# 1264         99        3                            Dizziness and giddiness
# 1265         98        3                      Cord compression, unspecified
# 1266         98        3                                           Dyspnoea
#
#       Disposition  KTAS_expert  Error_group  Length of stay_min  \
# 1262            2            2            0                1995
# 1263            1            4            0                1000
# 1264            1            3            0                 310
# 1265            7            3            0                 475
# 1266            2            3            0                 887
#
#       KTAS duration_min  mistriage
# 1262                3.0          0
# 1263                2.0          0
# 1264                4.0          0
# 1265                5.0          0
# 1266                2.0          0

# %% [markdown]
# Task 1.
# What kind of information does this dataset contain?
#     It contains a patient labelled from 0 to 1266 as well as some variable collected during their ED visit. This includes vital signs, their KTAS, sex, age, injury, pain, and chief_complaint
# What does one row represent?
#     A patient and their variables
# What does one column represent?
#     One type of variable

# %%
df.shape
print("Number of rows:",df.shape[0])
print("Numbers of columns:",df.shape[1])
df.columns.tolist()
# Out:
# Number of rows: 1267
# Numbers of columns: 24
# ['Group',
#  'Sex',
#  'Age',
#  'Patients number per hour',
#  'Arrival mode',
#  'Injury',
#  'Chief_complain',
#  'Mental',
#  'Pain',
#  'NRS_pain',
#  'SBP',
#  'DBP',
#  'HR',
#  'RR',
#  'BT',
#  'Saturation',
#  'KTAS_RN',
#  'Diagnosis in ED',
#  'Disposition',
#  'KTAS_expert',
#  'Error_group',
#  'Length of stay_min',
#  'KTAS duration_min',
#  'mistriage']

# %% [markdown]
# This dataset contains a total of 1267 rows and 24 columns.
# Each row represents one emergency department patient record.
# Each column represents a type of variable taken from the patient's record

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1267 entries, 0 to 1266
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Group                     1267 non-null   int64
#  1   Sex                       1267 non-null   int64
#  2   Age                       1267 non-null   int64
#  3   Patients number per hour  1267 non-null   int64
#  4   Arrival mode              1267 non-null   int64
#  5   Injury                    1267 non-null   int64
#  6   Chief_complain            1267 non-null   str
#  7   Mental                    1267 non-null   int64
#  8   Pain                      1267 non-null   int64
#  9   NRS_pain                  1267 non-null   str
#  10  SBP                       1267 non-null   str
#  11  DBP                       1267 non-null   str
#  12  HR                        1267 non-null   str
#  13  RR                        1267 non-null   str
#  14  BT                        1267 non-null   str
#  15  Saturation                579 non-null    str
#  16  KTAS_RN                   1267 non-null   int64
#  17  Diagnosis in ED           1265 non-null   str
#  18  Disposition               1267 non-null   int64
#  19  KTAS_expert               1267 non-null   int64
#  20  Error_group               1267 non-null   int64
#  21  Length of stay_min        1267 non-null   int64
#  22  KTAS duration_min         1267 non-null   float64
#  23  mistriage                 1267 non-null   int64
# dtypes: float64(1), int64(14), str(9)
# memory usage: 237.7 KB

# %% [markdown]
# numeric columns: age, KTAS duration_min, length of stay_min
# string/catergorical columns:chief complain, Diagnosis in ED
# columns that contain numbers but actually represent categories: sex,group,arrival mode,mental,pain,disposition,KTAS

# %%
df.describe()
print(f'Mean age: {df["Age"].mean():.2f}')
print(f'Median age:" {df["Age"].median():.2f}')
print(f'Minimum age:" {df["Age"].min():.2f}')
print(f'Maximum age:" {df["Age"].max():.2f}')
# Out:
# Mean age: 54.42
# Median age:" 57.00
# Minimum age:" 16.00
# Maximum age:" 96.00

# %%
df["Chief_complain"].head(10)
# Out:
# 0        right ocular pain
# 1       right forearm burn
# 2             arm pain, Lt
# 3          ascites tapping
# 4          distension, abd
# 5                    fever
# 6    With chest discomfort
# 7              pain, chest
# 8      LBP - Low back pain
# 9           Eczema, Eyelid
# Name: Chief_complain, dtype: str

# %%
df["Age"].head(10)
# Out:
# 0    71
# 1    56
# 2    68
# 3    71
# 4    58
# 5    54
# 6    49
# 7    78
# 8    32
# 9    38
# Name: Age, dtype: int64

# %%
df[["Age", "Sex", "SBP", "HR"]].head(6)
# Out:
#    Age  Sex  SBP   HR
# 0   71    2  160   84
# 1   56    1  137   60
# 2   68    1  130  102
# 3   71    2  139   88
# 4   58    2   91   93
# 5   54    1  140   94

# %%
elderly = df[df["Age"] >= 65]
print("Number of patients aged 65 of older:",len(elderly))
elderly.head()
# Out:
# Number of patients aged 65 of older: 467
#     Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 0       2    2   71                         3             3       2
# 2       2    1   68                         8             2       2
# 3       1    2   71                         8             1       1
# 7       1    2   78                        14             3       1
# 15      2    1   65                        12             4       1
#
#        Chief_complain  Mental  Pain NRS_pain  SBP  DBP   HR  RR    BT  \
# 0   right ocular pain       1     1        2  160  100   84  18  36.6
# 2        arm pain, Lt       1     1        2  130   80  102  20  36.6
# 3     ascites tapping       1     1        3  139   94   88  20  36.5
# 7         pain, chest       1     1        3  169   86   80  20    36
# 15           headache       1     1        3  140  100   80  20  36.0
#
#    Saturation  KTAS_RN                               Diagnosis in ED  \
# 0         100        2                              Corneal abrasion
# 2          98        4  Fracture of surgical neck of humerus, closed
# 3         NaN        4        Alcoholic liver cirrhosis with ascites
# 7         NaN        2                       Acute coronary syndrome
# 15         98        3         Subarachnoid haemorrhage, unspecified
#
#     Disposition  KTAS_expert  Error_group  Length of stay_min  \
# 0             1            4            2                  86
# 2             2            5            4                 862
# 3             1            5            6                 108
# 7             1            3            2                 247
# 15            2            4            4                 153
#
#     KTAS duration_min  mistriage
# 0                5.00          1
# 2                1.00          1
# 3                9.83          1
# 7               10.23          1
# 15               3.00          1

# %%
df["HR"] = pd.to_numeric(df["HR"], errors = "coerce")
high_hr = df[df["HR"] >= 100]
print("Number of patients with HR >= 100:", len(high_hr))
high_hr.head()
# Out:
# Number of patients with HR >= 100: 250
#     Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 2       2    1   68                         8             2       2
# 12      2    1   53                        10             3       1
# 14      1    2   58                         4             3       1
# 17      2    2   53                        12             2       2
# 19      1    2   38                         3             2       1
#
#        Chief_complain  Mental  Pain NRS_pain  SBP DBP     HR  RR    BT  \
# 2        arm pain, Lt       1     1        2  130  80  102.0  20  36.6
# 12    epigastric pain       1     1        3  120  80  106.0  20  36.2
# 14           headache       1     1        3  135  82  106.0  20  37.6
# 17         Open Wound       1     1        4  130  80  100.0  20  36.4
# 19  Gingival swelling       1     1        4  133  93  109.0  16  36.5
#
#    Saturation  KTAS_RN                               Diagnosis in ED  \
# 2          98        4  Fracture of surgical neck of humerus, closed
# 12         98        3                  Infectious or septic colitis
# 14        NaN        3                        Infective endocarditis
# 17         97        2       Open wound of other parts of head, face
# 19        NaN        3                         Odontogenic infection
#
#     Disposition  KTAS_expert  Error_group  Length of stay_min  \
# 2             2            5            4                 862
# 12            1            4            4                8067
# 14            2            4            4                1318
# 17            2            3            2                 613
# 19            1            4            4                 349
#
#     KTAS duration_min  mistriage
# 2                1.00          1
# 12               5.00          1
# 14               9.88          1
# 17               4.00          1
# 19              12.45          1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1267 entries, 0 to 1266
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Group                     1267 non-null   int64
#  1   Sex                       1267 non-null   int64
#  2   Age                       1267 non-null   int64
#  3   Patients number per hour  1267 non-null   int64
#  4   Arrival mode              1267 non-null   int64
#  5   Injury                    1267 non-null   int64
#  6   Chief_complain            1267 non-null   str
#  7   Mental                    1267 non-null   int64
#  8   Pain                      1267 non-null   int64
#  9   NRS_pain                  1267 non-null   str
#  10  SBP                       1267 non-null   str
#  11  DBP                       1267 non-null   str
#  12  HR                        1247 non-null   float64
#  13  RR                        1267 non-null   str
#  14  BT                        1267 non-null   str
#  15  Saturation                579 non-null    str
#  16  KTAS_RN                   1267 non-null   int64
#  17  Diagnosis in ED           1265 non-null   str
#  18  Disposition               1267 non-null   int64
#  19  KTAS_expert               1267 non-null   int64
#  20  Error_group               1267 non-null   int64
#  21  Length of stay_min        1267 non-null   int64
#  22  KTAS duration_min         1267 non-null   float64
#  23  mistriage                 1267 non-null   int64
# dtypes: float64(2), int64(14), str(8)
# memory usage: 237.7 KB

# %%
df["Saturation"] = pd.to_numeric(df["Saturation"], errors = "coerce")
low_spo2 = df[df["Saturation"] < 95]
print("Number of patients with oxygen saturation below 95:", len(low_spo2))
low_spo2.head(2)
# Out:
# Number of patients with oxygen saturation below 95: 47
#      Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 61       2    1   70                         8             2       1
# 132      2    2   82                         6             4       1
#
#     Chief_complain  Mental  Pain NRS_pain  SBP  DBP     HR  RR    BT  \
# 61         dyspnea       2     1        3   ??   ??   96.0  22  36.3
# 132        dyspnea       1     0    #BOÞ!  150  100  116.0  26  37.0
#
#      Saturation  KTAS_RN                   Diagnosis in ED  Disposition  \
# 61         78.0        2                          Dyspnoea            6
# 132        68.0        2  Bacterial pneumonia, unspecified            2
#
#      KTAS_expert  Error_group  Length of stay_min  KTAS duration_min  \
# 61             1            1                 593                2.0
# 132            1            1                9270                2.0
#
#      mistriage
# 61           2
# 132          2

# %%
df["Saturation"] = pd.to_numeric(df["Saturation"], errors = "coerce")
result = df[(df["Saturation"] < 95) & (df["Age"] >= 65)]
print("Number of senior patients with oxygen saturation below 95:", len(result))
result.head()
# Out:
# Number of senior patients with oxygen saturation below 95: 32
#      Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 61       2    1   70                         8             2       1
# 132      2    2   82                         6             4       1
# 134      2    1   92                         9             3       1
# 140      2    2   73                         8             3       1
# 153      2    2   65                         7             2       2
#
#     Chief_complain  Mental  Pain NRS_pain  SBP  DBP     HR  RR    BT  \
# 61         dyspnea       2     1        3   ??   ??   96.0  22  36.3
# 132        dyspnea       1     0    #BOÞ!  150  100  116.0  26  37.0
# 134        dyspnea       1     0    #BOÞ!  150   90  110.0  26  36.5
# 140        dyspnea       1     0    #BOÞ!  140   80   86.0  24  36.4
# 153  mental change       3     0    #BOÞ!   70   ??  100.0  20  36.0
#
#      Saturation  KTAS_RN                                    Diagnosis in ED  \
# 61         78.0        2                                           Dyspnoea
# 132        68.0        2                   Bacterial pneumonia, unspecified
# 134        88.0        3  Other specified chronic obstructive pulmonary ...
# 140        89.0        3                                                NaN
# 153        94.0        2  Traumatic subdural hemorrhage without open int...
#
#      Disposition  KTAS_expert  Error_group  Length of stay_min  \
# 61             6            1            1                 593
# 132            2            1            1                9270
# 134            2            2            1              699091
# 140            1            2            2                 518
# 153            5            1            5                 150
#
#      KTAS duration_min  mistriage
# 61                 2.0          2
# 132                2.0          2
# 134                4.0          2
# 140                2.0          2
# 153                2.0          2

# %%
df.sort_values("Age",ascending=False).head(10)
# Out:
#       Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 1209      2    2   96                         7             4       1
# 1208      1    1   95                         9             7       1
# 448       2    1   94                         5             3       1
# 1207      1    2   93                        12             1       1
# 134       2    1   92                         9             3       1
# 809       1    2   91                        12             4       1
# 1206      1    2   91                        11             6       1
# 133       1    1   90                         9             2       1
# 49        2    2   89                         8             4       1
# 554       2    1   89                         3             2       1
#
#                Chief_complain  Mental  Pain NRS_pain  SBP  DBP     HR  RR  \
# 1209         general weakness       1     0    #BOÞ!   90   60   68.0  20
# 1208  Hyperkalemia (disorder)       1     0    #BOÞ!  137   71   58.0  18
# 448       abdominal pain, LUQ       1     1        3  170  100   68.0  20
# 1207                dizziness       1     0    #BOÞ!  121   70   76.0  18
# 134                   dyspnea       1     0    #BOÞ!  150   90  110.0  26
# 809                     fever       3     0    #BOÞ!  142   86  110.0  24
# 1206               medication       1     0    #BOÞ!  131   76   62.0  18
# 133             acute dyspnea       1     1    #BOÞ!   65   45  100.0  30
# 49                     melena       1     0    #BOÞ!  100   60   74.0  20
# 554           Left chest pain       1     1        4  100   60   48.0  20
#
#         BT  Saturation  KTAS_RN  \
# 1209  36.2        91.0        2
# 1208  36.8         NaN        3
# 448   36.1        99.0        4
# 1207  36.6         NaN        3
# 134   36.5        88.0        3
# 809   38.6         NaN        2
# 1206  36.5         NaN        5
# 133     36         NaN        2
# 49    36.2        95.0        2
# 554   36.0        95.0        2
#
#                                         Diagnosis in ED  Disposition  \
# 1209             Pericardial effusion (noninflammatory)            2
# 1208                                            Ascites            1
# 448                          Unspecified abdominal pain            1
# 1207                                          Dizziness            1
# 134   Other specified chronic obstructive pulmonary ...            2
# 809                                Aspiration pneumonia            2
# 1206      Benign prostatic hyperplasia with obstruction            1
# 133                               Colon cancer, sigmoid            5
# 49               Acute with haemorrhage, duodenal ulcer            7
# 554                                    Other chest pain            1
#
#       KTAS_expert  Error_group  Length of stay_min  KTAS duration_min  \
# 1209            2            0               20076               4.00
# 1208            3            0                   0              16.00
# 448             4            0                 283               2.00
# 1207            3            0                   0              15.00
# 134             2            1              699091               4.00
# 809             2            0                   1               4.00
# 1206            5            0                  80               6.30
# 133             1            1                 126               9.58
# 49              3            7                8397               4.00
# 554             2            0                 148               2.00
#
#       mistriage
# 1209          0
# 1208          0
# 448           0
# 1207          0
# 134           2
# 809           0
# 1206          0
# 133           2
# 49            1
# 554           0

# %%
df.sort_values("HR",ascending=False).head(10)
# Out:
#       Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 454       1    1   85                        10             3       1
# 32        1    1   74                         8             3       1
# 152       2    2   63                         9             4       1
# 525       1    1   60                        10             3       1
# 1108      1    2   72                        14             2       1
# 370       1    1   59                         5             3       1
# 1050      1    1   65                         7             3       1
# 129       1    2   67                         9             3       1
# 621       1    2   54                         5             3       1
# 620       1    2   54                         5             3       1
#
#            Chief_complain  Mental  Pain NRS_pain  SBP  DBP     HR  RR    BT  \
# 454           palpitation       1     1        4  118   69  148.0  20  37.3
# 32            palpitation       1     1    #BOÞ!   91   74  145.0  18  36.8
# 152         mental change       3     0    #BOÞ!  110   70  140.0  24  36.2
# 525              abd pain       1     1        4  198  117  137.0  18  36.6
# 1108  rigth side weakness       1     0    #BOÞ!  204   98  137.0  18    38
# 370              LLQ pain       1     1        3  142   89  135.0  20  36.8
# 1050          palpitation       1     0    #BOÞ!  143   87  131.0  20    36
# 129         fever & chill       1     0    #BOÞ!  143   70  130.0  20  38.1
# 621          abdomen pain       1     1        5  137   77  129.0  20  37.8
# 620          abdomen pain       1     1        5  137   77  129.0  20  37.8
#
#       Saturation  KTAS_RN                          Diagnosis in ED  \
# 454          NaN        3                           Atrial flutter
# 32           NaN        2  Paroxysmal supraventricular tachycardia
# 152         92.0        3              Encephalopathy, unspecified
# 525          NaN        3                        Urinary retension
# 1108         NaN        3           Metastatic cancer to the brain
# 370          NaN        3                             Constipation
# 1050         NaN        3                              Palpitation
# 129          NaN        4                                    Fever
# 621          NaN        3           Metastatic cancer to the liver
# 620          NaN        3                            Liver abscess
#
#       Disposition  KTAS_expert  Error_group  Length of stay_min  \
# 454             2            3            0                 296
# 32              1            3            1                  95
# 152             5            2            5                8188
# 525             1            3            0                 280
# 1108            2            3            0                1437
# 370             1            3            0                  76
# 1050            1            3            0                 110
# 129             1            2            1                 267
# 621             2            3            0                 478
# 620             2            3            0                 478
#
#       KTAS duration_min  mistriage
# 454                7.23          0
# 32                 8.10          1
# 152                4.00          2
# 525                8.33          0
# 1108              11.02          0
# 370                7.00          0
# 1050               9.53          0
# 129                3.60          2
# 621               17.23          0
# 620               17.23          0

# %%
df.sort_values("Saturation",ascending=True).head(10)
# Out:
#       Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 1148      2    2   77                         7             2       1
# 132       2    2   82                         6             4       1
# 1167      2    1   79                         8             4       1
# 434       2    2   80                        10             3       1
# 61        2    1   70                         8             2       1
# 988       2    1   54                         3             3       1
# 845       2    2   22                        10             2       1
# 911       2    2   39                        10             4       1
# 968       2    1   51                         1             4       1
# 134       2    1   92                         9             3       1
#
#            Chief_complain  Mental  Pain NRS_pain  SBP  DBP     HR  RR    BT  \
# 1148            dizziness       1     0    #BOÞ!  130   80   56.0  20  36.2
# 132               dyspnea       1     0    #BOÞ!  150  100  116.0  26  37.0
# 1167  blood tinged sputum       1     0    #BOÞ!  130   80   60.0  24  36.4
# 434               dyspnea       1     1        3  120   80  118.0  20  36.0
# 61                dyspnea       2     1        3   ??   ??   96.0  22  36.3
# 988                 cough       1     0    #BOÞ!  180  100  108.0  24  36.6
# 845         mental change       3     0    #BOÞ!  100   60   98.0  24  37.6
# 911       Confusion state       3     0    #BOÞ!   80   50   72.0  20  36.8
# 968         mental change       4     0    #BOÞ!   60   ??   72.0  ??  35.7
# 134               dyspnea       1     0    #BOÞ!  150   90  110.0  26  36.5
#
#       Saturation  KTAS_RN                                    Diagnosis in ED  \
# 1148        20.0        3         Horizontal canal benign positional vertigo
# 132         68.0        2                   Bacterial pneumonia, unspecified
# 1167        74.0        2                                        Haemoptysis
# 434         76.0        2          Acute and subacute infective endocarditis
# 61          78.0        2                                           Dyspnoea
# 988         80.0        3                                           Dyspnoea
# 845         85.0        2                                             Stupor
# 911         86.0        2                               Hepatorenal syndrome
# 968         86.0        1       Cardiac arrest with successful resuscitation
# 134         88.0        3  Other specified chronic obstructive pulmonary ...
#
#       Disposition  KTAS_expert  Error_group  Length of stay_min  \
# 1148            1            3            0                8258
# 132             2            1            1                9270
# 1167            6            2            0                9378
# 434             2            2            0                9984
# 61              6            1            1                 593
# 988             2            3            0               10895
# 845             1            2            0                8703
# 911             2            2            0                 518
# 968             6            1            0                 392
# 134             2            2            1              699091
#
#       KTAS duration_min  mistriage
# 1148                1.0          0
# 132                 2.0          2
# 1167                5.0          0
# 434                 4.0          0
# 61                  2.0          2
# 988                 4.0          0
# 845                 4.0          0
# 911                 5.0          0
# 968                 5.0          0
# 134                 4.0          2

# %%
df [["Age","Sex","HR","Saturation"]].sort_values("Age",ascending=False).head(10)
# Out:
#       Age  Sex     HR  Saturation
# 1209   96    2   68.0        91.0
# 1208   95    1   58.0         NaN
# 448    94    1   68.0        99.0
# 1207   93    2   76.0         NaN
# 134    92    1  110.0        88.0
# 809    91    2  110.0         NaN
# 1206   91    2   62.0         NaN
# 133    90    1  100.0         NaN
# 49     89    2   74.0        95.0
# 554    89    1   48.0        95.0

# %%
df["Sex"].value_counts()
# Out:
# Sex
# 2    661
# 1    606
# Name: count, dtype: int64

# %%
df["KTAS_expert"].value_counts()
# Out:
# KTAS_expert
# 3    487
# 4    459
# 2    220
# 5     75
# 1     26
# Name: count, dtype: int64

# %% [markdown]
# 1. What is the name of the downloaded CSV file?
#     data.csv
# 2. How many rows and columns are in the dataset?
#     There were 1267 rows and 24 columns.
# 3. What types of patient information are included in the dataset?
#     It includes, sex, age, arrival mode, injury, chief complaint,mental state, pain, NRS_pain, vital signs,KTAS RN,Diagnosis in ED,            Disposition,KTAS expert,Error_group,Length of stay in mins, KTAS duration in mins,mistriage.
# 4. What are the mean age and maximum age?
#     The mean was 54.42 and the max was 96.
# 5. How many patients are aged 65 or older?
#     There are 467 senior patients.
# 6. How many patients have an oxygen saturation below 95?
#     There are 47 patients with a SpO2 below 95, and one of them had a SpO2 of 20, so thats very bad.
# 7. Which expert KTAS level appears most frequently?
#     KTAS level 3.
# 8. What was the most difficult part of examining the dataset?
#     The fact that some of the numbers were actually strings and probaly trying to understand how a notebook actually works.
#     Also the file it's self was a little wonky, and tbh, idek how my advisor fixed it but she did so thats very cool.
